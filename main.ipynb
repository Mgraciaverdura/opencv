# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import random

# %matplotlib inline

# %%
print(cv2.getBuildInformation())
# Out:
# General configuration for OpenCV 4.1.0 =====================================
#   Version control:               4.1.0
#
#   Platform:
#     Timestamp:                   2019-04-11T16:20:29Z
#     Host:                        Linux 4.4.0-101-generic x86_64
#     CMake:                       3.9.0
#     CMake generator:             Unix Makefiles
#     CMake build tool:            /usr/bin/gmake
#     Configuration:               Release
#
#   CPU/HW features:
#     Baseline:                    SSE SSE2 SSE3
#       requested:                 SSE3
#     Dispatched code generation:  SSE4_1 SSE4_2 FP16 AVX AVX2
#       requested:                 SSE4_1 SSE4_2 AVX FP16 AVX2 AVX512_SKX
#       SSE4_1 (13 files):         + SSSE3 SSE4_1
#       SSE4_2 (1 files):          + SSSE3 SSE4_1 POPCNT SSE4_2
#       FP16 (0 files):            + SSSE3 SSE4_1 POPCNT SSE4_2 FP16 AVX
#       AVX (4 files):             + SSSE3 SSE4_1 POPCNT SSE4_2 AVX
# ...

# %%
img = cv2.imread('mountain.jpg', cv2.IMREAD_COLOR)

# %%
print(img.shape)
print(img.size)
print(img.dtype)
# Out:
# (640, 960, 3)
# 1843200
# uint8

# %%
plt.figure(figsize=(16, 16))
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB), interpolation='bicubic')
plt.xticks([])
plt.yticks([])
#plt.axvline(img.shape[1] / 2, c='r', linewidth=4) #axisline
plt.show()

# %%
px = img[100, 100]

# %%
px
# Out:
# array([167, 146, 125], dtype=uint8)

# %%
img[100, 100] = [255, 255, 255]

# %%
img = cv2.imread('beach.jpg', cv2.IMREAD_COLOR)

# %%
plt.figure(figsize=(16, 16))
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB), interpolation='bicubic')
plt.xticks([])
plt.yticks([])
#plt.axvline(img.shape[1] / 2, c='r', linewidth=4)
plt.show()

# %%
print(img.shape)
print(img.size)
print(img.dtype)
# Out:
# (576, 1024, 3)
# 1769472
# uint8

# %%
px = img[100, 100]

# %%
img[100, 100] = [255, 255, 255]

# %%
square_size = 50
HEIGHT = img.shape[0]
WIDTH = img.shape[1]

img[100:100, 100:100] = [255, 255, 255]

img[HEIGHT//3:HEIGHT//3+square_size, 
    WIDTH//3:WIDTH//3+square_size] = img[HEIGHT//2:HEIGHT//2+square_size, 
                                        WIDTH//2:WIDTH//2+square_size]

# %%
#cv2.namedWindow("image_modified", cv2.WINDOW_NORMAL)
#cv2.imshow('image_modified', img)
#cv2.resizeWindow("image_modified", 600, 600);
#cv2.waitKey(0)
#cv2.destroyAllWindows()

# %%
img1 = cv2.imread('mountain.jpg', cv2.IMREAD_COLOR)
img2 = cv2.imread('beach.jpg', cv2.IMREAD_COLOR)
img2_resized = cv2.resize(img2, img1.shape[:2][::-1], interpolation=cv2.INTER_AREA)

# %%
# Out:
# array([[[249, 179,  95],
#         [249, 179,  95],
#         [249, 179,  95],
#         ...,
#         [247, 174, 106],
#         [246, 173, 105],
#         [246, 173, 105]],
#
#        [[250, 180,  96],
#         [250, 180,  96],
#         [250, 180,  96],
#         ...,
#         [247, 174, 106],
#         [247, 174, 106],
#         [247, 174, 106]],
#
#        [[250, 180,  96],
#         [250, 180,  96],
#         [250, 180,  96],
#         ...,
#         [248, 175, 108],
#         [248, 175, 108],
#         [248, 175, 107]],
#
#        ...,
#
#        [[195, 209, 228],
#         [195, 209, 228],
#         [195, 209, 228],
#         ...,
#         [199, 209, 218],
#         [199, 208, 217],
#         [198, 207, 216]],
#
#        [[195, 209, 228],
#         [195, 209, 228],
#         [195, 209, 228],
#         ...,
#         [199, 208, 217],
#         [199, 208, 217],
#         [199, 208, 217]],
#
#        [[196, 210, 229],
#         [196, 210, 229],
#         [196, 210, 229],
# ...
